# %%
import pandas as pd

# %%
data = pd.read_csv('../flights.csv', nrows = 1000)

# %%
df = pd.DataFrame(data)

# %%
requiredDf = df.loc[:,['YEAR', "DAY_OF_WEEK", "AIRLINE", "FLIGHT_NUMBER", "TAIL_NUMBER",
            "ORIGIN_AIRPORT", "DESTINATION_AIRPORT", "SCHEDULED_DEPARTURE",
            "AIR_TIME", "DISTANCE", "SCHEDULED_ARRIVAL"]]
requiredDf
# Out:
#      YEAR  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0    2015            4      AS             98      N407AS            ANC
# 1    2015            4      AA           2336      N3KUAA            LAX
# 2    2015            4      US            840      N171US            SFO
# 3    2015            4      AA            258      N3HYAA            LAX
# 4    2015            4      AS            135      N527AS            SEA
# ..    ...          ...     ...            ...         ...            ...
# 995  2015            4      WN            552      N291WN            SAT
# 996  2015            4      WN           3239      N905WN            TPA
# 997  2015            4      WN           1912      N554WN            TUS
# 998  2015            4      UA           1660      N17730            SNA
# 999  2015            4      US            445      N187US            RDU
#
#     DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  AIR_TIME  DISTANCE  \
# ...

# %%
# ANC SEA
x = requiredDf.loc[(requiredDf.ORIGIN_AIRPORT == "ANC") & (requiredDf.DESTINATION_AIRPORT == "SEA")]
y = x.loc[:,'DISTANCE']
y
# Out:
# 0      1448
# 15     1448
# 16     1448
# 32     1448
# 38     1448
# 47     1448
# 61     1448
# 890    1448
# Name: DISTANCE, dtype: int64

# %%
frame = pd.DataFrame(None, [n for n in range(1, 24, 1)], ['A', 'B', 'C'])
frame.loc[pd.
# Out:
#       A    B    C
# 1   NaN  NaN  NaN
# 2   NaN  NaN  NaN
# 3   NaN  NaN  NaN
# 4   NaN  NaN  NaN
# 5   NaN  NaN  NaN
# 6   NaN  NaN  NaN
# 7   NaN  NaN  NaN
# 8   NaN  NaN  NaN
# 9   NaN  NaN  NaN
# 10  NaN  NaN  NaN
# 11  NaN  NaN  NaN
# 12  NaN  NaN  NaN
# 13  NaN  NaN  NaN
# 14  NaN  NaN  NaN
# 15  NaN  NaN  NaN
# 16  NaN  NaN  NaN
# 17  NaN  NaN  NaN
# 18  NaN  NaN  NaN
# 19  NaN  NaN  NaN
# 20  NaN  NaN  NaN
# 21  NaN  NaN  NaN
# 22  NaN  NaN  NaN
# 23  NaN  NaN  NaN
